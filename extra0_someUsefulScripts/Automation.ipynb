# %% [markdown]
# # 1. OS Related

# %% [markdown]
# ### 1.1 Traverse folder

# %%
import os

"""
os.walk() will generate 3 parameters after execution:
1. current path
2. all folders under current path (list)
3. all files under current path (list)
"""
for dirpath, dirnames, filenames in os.walk(r'C:\\tools\\zookeeper\\apache-zookeeper-3.5.5'):
    print(f'open folder {dirpath}') # current path
    if dirnames:
        print(dirnames) # all folders under current path
    if filenames:
        print(filenames) # all files under current path
    print('-' * 10)
# Out:
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5
# ['bin', 'conf', 'zookeeper-assembly', 'zookeeper-client', 'zookeeper-contrib', 'zookeeper-docs', 'zookeeper-it', 'zookeeper-jute', 'zookeeper-recipes', 'zookeeper-server']
# ['build.xml', 'excludeFindBugsFilter.xml', 'ivy.xml', 'ivysettings.xml', 'LICENSE.txt', 'NOTICE.txt', 'owaspSuppressions.xml', 'pom.xml', 'README.md', 'README_packaging.txt']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\bin
# ['README.txt', 'zkCleanup.sh', 'zkCli.cmd', 'zkCli.sh', 'zkEnv.cmd', 'zkEnv.sh', 'zkServer-initialize.sh', 'zkServer.cmd', 'zkServer.sh', 'zkTxnLogToolkit.cmd', 'zkTxnLogToolkit.sh']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\conf
# ['configuration.xsl', 'log4j.properties', 'zoo_sample.cfg']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-assembly
# ['src']
# ['pom.xml']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-assembly\src
# ['main']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-assembly\src\main
# ['assembly']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-assembly\src\main\assembly
# ['bin-package.xml', 'components.xml', 'source-package.xml']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-client
# ['zookeeper-client-c']
# ['pom.xml']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-client\zookeeper-client-c
# ['generated', 'include', 'src', 'tests']
# ['acinclude.m4', 'aminclude.am', 'c-doc.Doxyfile', 'ChangeLog', 'CMakeLists.txt', 'cmake_config.h.in', 'configure.ac', 'INSTALL', 'LICENSE', 'Makefile.am', 'NOTICE.txt', 'pom.xml', 'README']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-client\zookeeper-client-c\generated
# ['zookeeper.jute.c', 'zookeeper.jute.h']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-client\zookeeper-client-c\include
# ['proto.h', 'recordio.h', 'winconfig.h', 'zookeeper.h', 'zookeeper_log.h', 'zookeeper_version.h']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-client\zookeeper-client-c\src
# ['hashtable']
# ['addrvec.c', 'addrvec.h', 'cli.c', 'load_gen.c', 'mt_adaptor.c', 'recordio.c', 'st_adaptor.c', 'winport.c', 'winport.h', 'zk_adaptor.h', 'zk_hashtable.c', 'zk_hashtable.h', 'zk_log.c', 'zookeeper.c']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-client\zookeeper-client-c\src\hashtable
# ['hashtable.c', 'hashtable.h', 'hashtable_itr.c', 'hashtable_itr.h', 'hashtable_private.h', 'LICENSE.txt']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-client\zookeeper-client-c\tests
# ['CollectionUtil.h', 'CppAssertHelper.h', 'LibCMocks.cc', 'LibCMocks.h', 'LibCSymTable.cc', 'LibCSymTable.h', 'MocksBase.cc', 'MocksBase.h', 'PthreadMocks.cc', 'PthreadMocks.h', 'quorum.cfg', 'TestClient.cc', 'TestClientRetry.cc', 'TestDriver.cc', 'TestMulti.cc', 'TestOperations.cc', 'TestReadOnlyClient.cc', 'TestReconfig.cc', 'TestReconfigServer.cc', 'TestWatchers.cc', 'TestZookeeperClose.cc', 'TestZookeeperInit.cc', 'ThreadingUtil.cc', 'ThreadingUtil.h', 'Util.cc', 'Util.h', 'Vector.h', 'WatchUtil.h', 'wrappers-mt.opt', 'wrappers.opt', 'ZKMocks.cc', 'ZKMocks.h', 'zkServer.sh', 'ZooKeeperQuorumServer.cc', 'ZooKeeperQuorumServer.h']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib
# ['zookeeper-contrib-fatjar', 'zookeeper-contrib-huebrowser', 'zookeeper-contrib-loggraph', 'zookeeper-contrib-monitoring', 'zookeeper-contrib-rest', 'zookeeper-contrib-zkfuse', 'zookeeper-contrib-zkperl', 'zookeeper-contrib-zkpython', 'zookeeper-contrib-zktreeutil', 'zookeeper-contrib-zooinspector']
# ['build-contrib.xml', 'build.xml', 'pom.xml']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-fatjar
# ['src']
# ['build.xml', 'README.txt']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-fatjar\src
# ['main']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-fatjar\src\main
# ['java', 'resources']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-fatjar\src\main\java
# ['org']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-fatjar\src\main\java\org
# ['apache']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-fatjar\src\main\java\org\apache
# ['zookeeper']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-fatjar\src\main\java\org\apache\zookeeper
# ['util']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-fatjar\src\main\java\org\apache\zookeeper\util
# ['FatJarMain.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-fatjar\src\main\resources
# ['mainClasses']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-huebrowser
# ['zkui']
# ['README']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-huebrowser\zkui
# ['src']
# ['Makefile', 'setup.py']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-huebrowser\zkui\src
# ['zkui']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-huebrowser\zkui\src\zkui
# ['static', 'templates']
# ['forms.py', 'models.py', 'rest.py', 'settings.py', 'stats.py', 'urls.py', 'utils.py', 'views.py', 'windmilltests.py', '__init__.py']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-huebrowser\zkui\src\zkui\static
# ['art', 'css', 'help', 'js']
# ['bootstrap.js']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-huebrowser\zkui\src\zkui\static\art
# ['line_icons.png', 'zkui.png']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-huebrowser\zkui\src\zkui\static\css
# ['zkui.css']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-huebrowser\zkui\src\zkui\static\help
# ['index.html']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-huebrowser\zkui\src\zkui\static\js
# ['Source']
# ['package.yml']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-huebrowser\zkui\src\zkui\static\js\Source
# ['Zkui']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-huebrowser\zkui\src\zkui\static\js\Source\Zkui
# ['Zkui.js']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-huebrowser\zkui\src\zkui\templates
# ['clients.mako', 'create.mako', 'edit.mako', 'index.mako', 'shared_components.mako', 'tree.mako', 'view.mako']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-loggraph
# ['src']
# ['build.xml', 'ivy.xml', 'pom.xml', 'README.txt']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-loggraph\src
# ['main']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-loggraph\src\main
# ['java', 'resources']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-loggraph\src\main\java
# ['org']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-loggraph\src\main\java\org
# ['apache']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-loggraph\src\main\java\org\apache
# ['zookeeper']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-loggraph\src\main\java\org\apache\zookeeper
# ['graph']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-loggraph\src\main\java\org\apache\zookeeper\graph
# ['filterops', 'servlets']
# ['FilterException.java', 'FilterOp.java', 'FilterParser.java', 'JsonGenerator.java', 'Log4JEntry.java', 'Log4JSource.java', 'LogEntry.java', 'LogIterator.java', 'LogServer.java', 'LogSkipList.java', 'LogSource.java', 'MeasureThroughput.java', 'MergedLogSource.java', 'RandomAccessFileReader.java', 'TransactionEntry.java', 'TxnLogSource.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-loggraph\src\main\java\org\apache\zookeeper\graph\filterops
# ['AndOp.java', 'Arg.java', 'EqualsOp.java', 'GreaterThanOp.java', 'LessThanOp.java', 'NotOp.java', 'NumberArg.java', 'OrOp.java', 'StringArg.java', 'SymbolArg.java', 'XorOp.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-loggraph\src\main\java\org\apache\zookeeper\graph\servlets
# ['FileLoader.java', 'Fs.java', 'GraphData.java', 'JsonServlet.java', 'NumEvents.java', 'StaticContent.java', 'Throughput.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-loggraph\src\main\resources
# ['webapp']
# ['loggraph-dev.sh', 'loggraph.sh']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-loggraph\src\main\resources\webapp
# ['org']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-loggraph\src\main\resources\webapp\org
# ['apache']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-loggraph\src\main\resources\webapp\org\apache
# ['zookeeper']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-loggraph\src\main\resources\webapp\org\apache\zookeeper
# ['graph']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-loggraph\src\main\resources\webapp\org\apache\zookeeper\graph
# ['resources']
# ['log4j.properties']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-loggraph\src\main\resources\webapp\org\apache\zookeeper\graph\resources
# ['date.format.js', 'g.bar.js', 'g.dot.js', 'g.line.js', 'g.pie.js', 'g.raphael.js', 'load-big.gif', 'load.gif', 'loggraph.css', 'loggraph.js', 'loggraph.log.js', 'loggraph.server.js', 'loggraph.session.js', 'loggraph.stats.js', 'loggraph.ui.js', 'main.html', 'raphael.js', 'yui-min.js']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-monitoring
# ['cacti', 'ganglia', 'nagios']
# ['check_zookeeper.py', 'JMX-RESOURCES', 'README', 'test.py']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-monitoring\cacti
# ['README']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-monitoring\ganglia
# ['modpython.conf', 'README', 'Screenshot.png', 'zookeeper.pyconf', 'zookeeper_ganglia.py']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-monitoring\nagios
# ['hostgroups.cfg', 'README.txt', 'Screenshot-1.png', 'Screenshot.png', 'services.cfg', 'zookeeper.cfg']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest
# ['conf', 'src']
# ['build.xml', 'ivy.xml', 'NOTICE.txt', 'pom.xml', 'README.txt', 'rest.sh', 'SPEC.txt']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest\conf
# ['keys']
# ['log4j.properties', 'rest.properties']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest\conf\keys
# ['README', 'rest.cer', 'rest.jks']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest\src
# ['main', 'python', 'test']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest\src\main
# ['java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest\src\main\java
# ['org']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest\src\main\java\org
# ['apache']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest\src\main\java\org\apache
# ['zookeeper']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest\src\main\java\org\apache\zookeeper
# ['server']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest\src\main\java\org\apache\zookeeper\server
# ['jersey']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest\src\main\java\org\apache\zookeeper\server\jersey
# ['cfg', 'filters', 'jaxb', 'resources']
# ['RestMain.java', 'ZooKeeperService.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest\src\main\java\org\apache\zookeeper\server\jersey\cfg
# ['Credentials.java', 'Endpoint.java', 'HostPort.java', 'HostPortSet.java', 'RestCfg.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest\src\main\java\org\apache\zookeeper\server\jersey\filters
# ['HTTPBasicAuth.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest\src\main\java\org\apache\zookeeper\server\jersey\jaxb
# ['ZChildren.java', 'ZChildrenJSON.java', 'ZError.java', 'ZPath.java', 'ZSession.java', 'ZStat.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest\src\main\java\org\apache\zookeeper\server\jersey\resources
# ['JAXBContextResolver.java', 'KeeperExceptionMapper.java', 'RuntimeExceptionMapper.java', 'SessionsResource.java', 'ZErrorWriter.java', 'ZNodeResource.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest\src\python
# ['demo_master_election.py', 'demo_queue.py', 'README.txt', 'test.py', 'zkrest.py', 'zk_dump_tree.py']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest\src\test
# ['java']
# ['zkServer.sh']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest\src\test\java
# ['org']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest\src\test\java\org
# ['apache']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest\src\test\java\org\apache
# ['zookeeper']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest\src\test\java\org\apache\zookeeper
# ['server']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest\src\test\java\org\apache\zookeeper\server
# ['jersey']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-rest\src\test\java\org\apache\zookeeper\server\jersey
# ['Base.java', 'CreateTest.java', 'DeleteTest.java', 'ExistsTest.java', 'GetChildrenTest.java', 'GetTest.java', 'RestTestSuite.java', 'RootTest.java', 'SessionTest.java', 'SetTest.java', 'WadlTest.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zkfuse
# ['src']
# ['build.xml', 'configure.ac', 'Makefile.am', 'README.txt']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zkfuse\src
# ['blockingqueue.h', 'doxygen.cfg', 'event.cc', 'event.h', 'log.cc', 'log.h', 'log4cxx.properties', 'Makefile.am', 'mutex.h', 'thread.cc', 'thread.h', 'zkadapter.cc', 'zkadapter.h', 'zkfuse.cc']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zkperl
# ['build', 't']
# ['build.xml', 'Changes', 'LICENSE', 'Makefile.PL', 'MANIFEST', 'NOTICE', 'README', 'typemap', 'ZooKeeper.pm', 'ZooKeeper.xs']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zkperl\build
# ['check_zk_version.c', 'check_zk_version.h']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zkperl\t
# ['10_invalid.t', '15_thread.t', '20_tie.t', '22_stat_tie.t', '24_watch_tie.t', '30_connect.t', '35_log.t', '40_basic.t', '45_class.t', '50_access.t', '60_watch.t', 'util.pl']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zkpython
# ['src']
# ['build.xml', 'ivy.xml', 'README']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zkpython\src
# ['c', 'examples', 'python', 'test']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zkpython\src\c
# ['pyzk_docstrings.h', 'zookeeper.c']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zkpython\src\examples
# ['README', 'watch_znode_for_changes.py']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zkpython\src\python
# ['setup.py', 'zk.py']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zkpython\src\test
# ['acl_test.py', 'async_test.py', 'callback_test.py', 'clientid_test.py', 'close_deadlock_test.py', 'connection_test.py', 'create_test.py', 'delete_test.py', 'exists_test.py', 'get_set_test.py', 'run_tests.sh', 'zkServer.sh', 'zktestbase.py']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zktreeutil
# ['src', 'tests']
# ['build.xml', 'configure.ac', 'Makefile.am', 'README.txt']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zktreeutil\src
# ['Makefile.am', 'SimpleTree.h', 'ZkAdaptor.cc', 'ZkAdaptor.h', 'ZkTreeUtil.cc', 'ZkTreeUtil.h', 'ZkTreeUtilMain.cc']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zktreeutil\tests
# ['zk_sample.xml']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector
# ['licences', 'src']
# ['build.xml', 'ivy.xml', 'NOTICE.txt', 'pom.xml', 'README.txt', 'TODO', 'zooInspector-dev.sh', 'zooInspector.cmd', 'zooInspector.sh']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\licences
# ['Apache Software Licence v2.0.txt']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src
# ['main']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main
# ['java', 'resources']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\java
# ['com', 'org']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\java\com
# ['nitido']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\java\com\nitido
# ['utils']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\java\com\nitido\utils
# ['toaster']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\java\com\nitido\utils\toaster
# ['Toaster.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\java\org
# ['apache']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\java\org\apache
# ['zookeeper']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\java\org\apache\zookeeper
# ['inspector', 'retry']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\java\org\apache\zookeeper\inspector
# ['encryption', 'gui', 'logger', 'manager']
# ['ZooInspector.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\java\org\apache\zookeeper\inspector\encryption
# ['BasicDataEncryptionManager.java', 'DataEncryptionManager.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\java\org\apache\zookeeper\inspector\gui
# ['actions', 'nodeviewer']
# ['about.html', 'IconResource.java', 'NodeViewersChangeListener.java', 'Toolbar.java', 'ZooInspectorAboutDialog.java', 'ZooInspectorConnectionPropertiesDialog.java', 'ZooInspectorNodeViewersDialog.java', 'ZooInspectorNodeViewersPanel.java', 'ZooInspectorPanel.java', 'ZooInspectorTreeViewer.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\java\org\apache\zookeeper\inspector\gui\actions
# ['AddNodeAction.java', 'DeleteNodeAction.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\java\org\apache\zookeeper\inspector\gui\nodeviewer
# ['NodeViewerACL.java', 'NodeViewerData.java', 'NodeViewerMetaData.java', 'ZooInspectorNodeViewer.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\java\org\apache\zookeeper\inspector\logger
# ['LoggerFactory.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\java\org\apache\zookeeper\inspector\manager
# ['NodeListener.java', 'NodesCache.java', 'Pair.java', 'ZooInspectorManager.java', 'ZooInspectorManagerImpl.java', 'ZooInspectorNodeManager.java', 'ZooInspectorNodeTreeManager.java', 'ZooInspectorReadOnlyManager.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\java\org\apache\zookeeper\retry
# ['ZooKeeperRetry.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources
# ['icons']
# ['defaultConnectionSettings.cfg', 'defaultNodeViewers.cfg', 'log4j.properties']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources\icons
# ['Tango']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources\icons\Tango
# ['16x16', '22x22', '24x24', '32x32']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources\icons\Tango\16x16
# ['actions', 'mimetypes', 'places', 'status']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources\icons\Tango\16x16\actions
# ['add.png', 'document-new.png', 'document-save.png', 'down.png', 'media-playback-start.png', 'media-playback-stop.png', 'remove.png', 'up.png', 'view-refresh.png']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources\icons\Tango\16x16\mimetypes
# ['text-x-generic.png']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources\icons\Tango\16x16\places
# ['folder.png', 'user-trash.png']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources\icons\Tango\16x16\status
# ['info.png']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources\icons\Tango\22x22
# ['actions', 'mimetypes', 'places', 'status']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources\icons\Tango\22x22\actions
# ['add.png', 'document-new.png', 'document-save.png', 'down.png', 'media-playback-start.png', 'media-playback-stop.png', 'remove.png', 'up.png', 'view-refresh.png']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources\icons\Tango\22x22\mimetypes
# ['text-x-generic.png']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources\icons\Tango\22x22\places
# ['folder.png', 'user-trash.png']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources\icons\Tango\22x22\status
# ['info.png']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources\icons\Tango\24x24
# ['actions', 'mimetypes', 'places', 'status']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources\icons\Tango\24x24\actions
# ['add.png', 'document-new.png', 'document-save.png', 'down.png', 'media-playback-start.png', 'media-playback-stop.png', 'remove.png', 'up.png', 'view-refresh.png']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources\icons\Tango\24x24\mimetypes
# ['text-x-generic.png']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources\icons\Tango\24x24\places
# ['folder.png', 'user-trash.png']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources\icons\Tango\24x24\status
# ['info.png']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources\icons\Tango\32x32
# ['actions', 'mimetypes', 'places', 'status']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources\icons\Tango\32x32\actions
# ['add.png', 'document-new.png', 'document-save.png', 'down.png', 'media-playback-start.png', 'media-playback-stop.png', 'remove.png', 'up.png', 'view-refresh.png']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources\icons\Tango\32x32\mimetypes
# ['text-x-generic.png']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources\icons\Tango\32x32\places
# ['folder.png', 'user-trash.png']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-contrib\zookeeper-contrib-zooinspector\src\main\resources\icons\Tango\32x32\status
# ['info.png']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-docs
# ['src']
# ['pom.xml']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-docs\src
# ['main']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-docs\src\main
# ['resources']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-docs\src\main\resources
# ['markdown']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-docs\src\main\resources\markdown
# ['html', 'images', 'skin']
# ['index.md', 'javaExample.md', 'recipes.md', 'releasenotes.md', 'zookeeperAdmin.md', 'zookeeperHierarchicalQuorums.md', 'zookeeperInternals.md', 'zookeeperJMX.md', 'zookeeperObservers.md', 'zookeeperOtherInfo.md', 'zookeeperOver.md', 'zookeeperProgrammers.md', 'zookeeperQuotas.md', 'zookeeperReconfig.md', 'zookeeperStarted.md', 'zookeeperTutorial.md']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-docs\src\main\resources\markdown\html
# ['footer.html', 'header.html']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-docs\src\main\resources\markdown\images
# ['2pc.jpg', 'bk-overview.jpg', 'favicon.ico', 'hadoop-logo.jpg', 'state_dia.dia', 'state_dia.jpg', 'zkarch.jpg', 'zkcomponents.jpg', 'zknamespace.jpg', 'zkperfreliability.jpg', 'zkperfRW-3.2.jpg', 'zkperfRW.jpg', 'zkservice.jpg', 'zookeeper_small.gif']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-docs\src\main\resources\markdown\skin
# ['basic.css', 'chapter.gif', 'chapter_open.gif', 'current.gif', 'getBlank.js', 'getMenu.js', 'header_white_line.gif', 'init.js', 'instruction_arrow.png', 'menu.js', 'page.gif', 'print.css', 'printer.gif', 'profile.css', 'prototype.js', 'screen.css']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-it
# ['src']
# ['README.txt']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-it\src
# ['test']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-it\src\test
# ['java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-it\src\test\java
# ['org']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-it\src\test\java\org
# ['apache']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-it\src\test\java\org\apache
# ['zookeeper']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-it\src\test\java\org\apache\zookeeper
# ['test']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-it\src\test\java\org\apache\zookeeper\test
# ['system']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-it\src\test\java\org\apache\zookeeper\test\system
# ['BaseSysTest.java', 'DuplicateNameException.java', 'GenerateLoad.java', 'Instance.java', 'InstanceContainer.java', 'InstanceManager.java', 'NoAssignmentException.java', 'NoAvailableContainers.java', 'QuorumPeerInstance.java', 'SimpleClient.java', 'SimpleSysTest.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-jute
# ['src']
# ['pom.xml']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-jute\src
# ['main', 'test']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-jute\src\main
# ['java', 'resources']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-jute\src\main\java
# ['org']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-jute\src\main\java\org
# ['apache']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-jute\src\main\java\org\apache
# ['jute']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-jute\src\main\java\org\apache\jute
# ['compiler']
# ['BinaryInputArchive.java', 'BinaryOutputArchive.java', 'CsvInputArchive.java', 'CsvOutputArchive.java', 'Index.java', 'InputArchive.java', 'OutputArchive.java', 'package.html', 'Record.java', 'RecordReader.java', 'RecordWriter.java', 'Utils.java', 'XmlInputArchive.java', 'XmlOutputArchive.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-jute\src\main\java\org\apache\jute\compiler
# ['generated']
# ['CGenerator.java', 'CppGenerator.java', 'CSharpGenerator.java', 'JavaGenerator.java', 'JBoolean.java', 'JBuffer.java', 'JByte.java', 'JCompType.java', 'JDouble.java', 'JField.java', 'JFile.java', 'JFloat.java', 'JInt.java', 'JLong.java', 'JMap.java', 'JRecord.java', 'JString.java', 'JType.java', 'JVector.java', 'package.html']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-jute\src\main\java\org\apache\jute\compiler\generated
# ['package.html', 'rcc.jj']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-jute\src\main\resources
# ['zookeeper.jute']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-jute\src\test
# ['java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-jute\src\test\java
# ['org']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-jute\src\test\java\org
# ['apache']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-jute\src\test\java\org\apache
# ['jute']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-jute\src\test\java\org\apache\jute
# ['BinaryInputArchiveTest.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes
# ['zookeeper-recipes-election', 'zookeeper-recipes-lock', 'zookeeper-recipes-queue']
# ['build-recipes.xml', 'build.xml', 'pom.xml', 'README.txt']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-election
# ['src']
# ['build.xml', 'pom.xml', 'README.txt']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-election\src
# ['main', 'test']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-election\src\main
# ['java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-election\src\main\java
# ['org']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-election\src\main\java\org
# ['apache']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-election\src\main\java\org\apache
# ['zookeeper']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-election\src\main\java\org\apache\zookeeper
# ['recipes']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-election\src\main\java\org\apache\zookeeper\recipes
# ['leader']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-election\src\main\java\org\apache\zookeeper\recipes\leader
# ['LeaderElectionAware.java', 'LeaderElectionSupport.java', 'LeaderOffer.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-election\src\test
# ['java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-election\src\test\java
# ['org']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-election\src\test\java\org
# ['apache']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-election\src\test\java\org\apache
# ['zookeeper']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-election\src\test\java\org\apache\zookeeper
# ['recipes']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-election\src\test\java\org\apache\zookeeper\recipes
# ['leader']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-election\src\test\java\org\apache\zookeeper\recipes\leader
# ['LeaderElectionSupportTest.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-lock
# ['src']
# ['build.xml', 'pom.xml', 'README.txt']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-lock\src
# ['main', 'test']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-lock\src\main
# ['c', 'java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-lock\src\main\c
# ['include', 'src', 'tests']
# ['acinclude.m4', 'aminclude.am', 'c-doc.Doxyfile', 'configure.ac', 'INSTALL', 'LICENSE', 'Makefile.am', 'README.txt']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-lock\src\main\c\include
# ['zoo_lock.h']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-lock\src\main\c\src
# ['zoo_lock.c']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-lock\src\main\c\tests
# ['TestClient.cc', 'TestDriver.cc', 'Util.cc', 'Util.h', 'zkServer.sh']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-lock\src\main\java
# ['org']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-lock\src\main\java\org
# ['apache']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-lock\src\main\java\org\apache
# ['zookeeper']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-lock\src\main\java\org\apache\zookeeper
# ['recipes']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-lock\src\main\java\org\apache\zookeeper\recipes
# ['lock']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-lock\src\main\java\org\apache\zookeeper\recipes\lock
# ['LockListener.java', 'ProtocolSupport.java', 'WriteLock.java', 'ZNodeName.java', 'ZooKeeperOperation.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-lock\src\test
# ['java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-lock\src\test\java
# ['org']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-lock\src\test\java\org
# ['apache']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-lock\src\test\java\org\apache
# ['zookeeper']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-lock\src\test\java\org\apache\zookeeper
# ['recipes']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-lock\src\test\java\org\apache\zookeeper\recipes
# ['lock']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-lock\src\test\java\org\apache\zookeeper\recipes\lock
# ['WriteLockTest.java', 'ZNodeNameTest.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-queue
# ['src']
# ['build.xml', 'pom.xml', 'README.txt']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-queue\src
# ['main', 'test']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-queue\src\main
# ['c', 'java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-queue\src\main\c
# ['include', 'src', 'tests']
# ['acinclude.m4', 'aminclude.am', 'c-doc.Doxyfile', 'configure.ac', 'INSTALL', 'LICENSE', 'Makefile.am', 'README.txt']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-queue\src\main\c\include
# ['zoo_queue.h']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-queue\src\main\c\src
# ['zoo_queue.c']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-queue\src\main\c\tests
# ['TestClient.cc', 'TestDriver.cc', 'Util.cc', 'Util.h', 'zkServer.sh']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-queue\src\main\java
# ['org']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-queue\src\main\java\org
# ['apache']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-queue\src\main\java\org\apache
# ['zookeeper']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-queue\src\main\java\org\apache\zookeeper
# ['recipes']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-queue\src\main\java\org\apache\zookeeper\recipes
# ['queue']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-queue\src\main\java\org\apache\zookeeper\recipes\queue
# ['DistributedQueue.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-queue\src\test
# ['java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-queue\src\test\java
# ['org']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-queue\src\test\java\org
# ['apache']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-queue\src\test\java\org\apache
# ['zookeeper']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-queue\src\test\java\org\apache\zookeeper
# ['recipes']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-queue\src\test\java\org\apache\zookeeper\recipes
# ['queue']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-recipes\zookeeper-recipes-queue\src\test\java\org\apache\zookeeper\recipes\queue
# ['DistributedQueueTest.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server
# ['bar', 'build', 'foo', 'src', 'version-2']
# ['pom.xml']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\bar
# ['version-2']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\bar\version-2
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\build
# ['test']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\build\test
# ['tmp']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\build\test\tmp
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\foo
# ['version-2']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\foo\version-2
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src
# ['main', 'test']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main
# ['java', 'resources']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\java
# ['org']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\java\org
# ['apache']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\java\org\apache
# ['zookeeper']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\java\org\apache\zookeeper
# ['admin', 'cli', 'client', 'common', 'jmx', 'server', 'util', 'version']
# ['AsyncCallback.java', 'ClientCnxn.java', 'ClientCnxnSocket.java', 'ClientCnxnSocketNetty.java', 'ClientCnxnSocketNIO.java', 'ClientWatchManager.java', 'CreateMode.java', 'Environment.java', 'JLineZNodeCompleter.java', 'KeeperException.java', 'Login.java', 'MultiResponse.java', 'MultiTransactionRecord.java', 'Op.java', 'OpResult.java', 'Quotas.java', 'SaslClientCallbackHandler.java', 'SaslServerPrincipal.java', 'ServerAdminClient.java', 'Shell.java', 'StatsTrack.java', 'Testable.java', 'Transaction.java', 'Version.java', 'WatchDeregistration.java', 'WatchedEvent.java', 'Watcher.java', 'ZKUtil.java', 'ZooDefs.java', 'ZooKeeper.java', 'ZooKeeperMain.java', 'ZooKeeperTestable.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\java\org\apache\zookeeper\admin
# ['ZooKeeperAdmin.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\java\org\apache\zookeeper\cli
# ['AclParser.java', 'AddAuthCommand.java', 'CliCommand.java', 'CliException.java', 'CliParseException.java', 'CliWrapperException.java', 'CloseCommand.java', 'CommandNotFoundException.java', 'CreateCommand.java', 'DeleteAllCommand.java', 'DeleteCommand.java', 'DelQuotaCommand.java', 'GetAclCommand.java', 'GetCommand.java', 'GetConfigCommand.java', 'ListQuotaCommand.java', 'Ls2Command.java', 'LsCommand.java', 'MalformedCommandException.java', 'MalformedPathException.java', 'ReconfigCommand.java', 'RemoveWatchesCommand.java', 'SetAclCommand.java', 'SetCommand.java', 'SetQuotaCommand.java', 'StatCommand.java', 'StatPrinter.java', 'SyncCommand.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\java\org\apache\zookeeper\client
# ['ConnectStringParser.java', 'FourLetterWordMain.java', 'HostProvider.java', 'StaticHostProvider.java', 'ZKClientConfig.java', 'ZooKeeperSaslClient.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\java\org\apache\zookeeper\common
# ['AtomicFileOutputStream.java', 'AtomicFileWritingIdiom.java', 'ClientX509Util.java', 'FileChangeWatcher.java', 'FileKeyStoreLoader.java', 'FileKeyStoreLoaderBuilderProvider.java', 'IOUtils.java', 'JKSFileLoader.java', 'KeyStoreFileType.java', 'KeyStoreLoader.java', 'NettyUtils.java', 'PathTrie.java', 'PathUtils.java', 'PEMFileLoader.java', 'QuorumX509Util.java', 'SSLContextAndOptions.java', 'StringUtils.java', 'Time.java', 'X509Exception.java', 'X509Util.java', 'ZKConfig.java', 'ZKHostnameVerifier.java', 'ZKTrustManager.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\java\org\apache\zookeeper\jmx
# ['CommonNames.java', 'ManagedUtil.java', 'MBeanRegistry.java', 'ZKMBeanInfo.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\java\org\apache\zookeeper\server
# ['admin', 'auth', 'command', 'persistence', 'quorum', 'util']
# ...
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\java\org\apache\zookeeper\server\command
# ['AbstractFourLetterCommand.java', 'CnxnStatResetCommand.java', 'CommandExecutor.java', 'ConfCommand.java', 'ConsCommand.java', 'DirsCommand.java', 'DumpCommand.java', 'EnvCommand.java', 'FourLetterCommands.java', 'IsroCommand.java', 'MonitorCommand.java', 'NopCommand.java', 'RuokCommand.java', 'SetTraceMaskCommand.java', 'StatCommand.java', 'StatResetCommand.java', 'TraceMaskCommand.java', 'WatchCommand.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\java\org\apache\zookeeper\server\persistence
# ['FilePadding.java', 'FileSnap.java', 'FileTxnLog.java', 'FileTxnSnapLog.java', 'SnapShot.java', 'TxnLog.java', 'TxnLogToolkit.java', 'Util.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\java\org\apache\zookeeper\server\quorum
# ['auth', 'flexible']
# ['AckRequestProcessor.java', 'AuthFastLeaderElection.java', 'BufferStats.java', 'CommitProcessor.java', 'Election.java', 'FastLeaderElection.java', 'Follower.java', 'FollowerBean.java', 'FollowerMXBean.java', 'FollowerRequestProcessor.java', 'FollowerZooKeeperServer.java', 'Leader.java', 'LeaderBean.java', 'LeaderElection.java', 'LeaderElectionBean.java', 'LeaderElectionMXBean.java', 'LeaderMXBean.java', 'LeaderRequestProcessor.java', 'LeaderSessionTracker.java', 'LeaderZooKeeperServer.java', 'Learner.java', 'LearnerHandler.java', 'LearnerSessionTracker.java', 'LearnerSnapshot.java', 'LearnerSnapshotThrottler.java', 'LearnerSyncRequest.java', 'LearnerZooKeeperServer.java', 'LocalPeerBean.java', 'LocalPeerMXBean.java', 'LocalSessionTracker.java', 'Observer.java', 'ObserverMXBean.java', 'ObserverRequestProcessor.java', 'ObserverZooKeeperServer.java', 'PrependableSocket.java', 'ProposalRequestProcessor.java', 'QuorumBean.java', 'QuorumCnxManager.java', 'QuorumMXBean.java', 'QuorumPeer.java', 'QuorumPeerConfig.java', 'QuorumPeerMain.java', 'QuorumStats.java', 'QuorumZooKeeperServer.java', 'ReadOnlyBean.java', 'ReadOnlyRequestProcessor.java', 'ReadOnlyZooKeeperServer.java', 'RemotePeerBean.java', 'RemotePeerMXBean.java', 'SendAckRequestProcessor.java', 'ServerBean.java', 'ServerMXBean.java', 'SnapshotThrottleException.java', 'StateSummary.java', 'SyncedLearnerTracker.java', 'UnifiedServerSocket.java', 'UpgradeableSessionTracker.java', 'Vote.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\java\org\apache\zookeeper\server\quorum\auth
# ['NullQuorumAuthLearner.java', 'NullQuorumAuthServer.java', 'QuorumAuth.java', 'QuorumAuthLearner.java', 'QuorumAuthServer.java', 'SaslQuorumAuthLearner.java', 'SaslQuorumAuthServer.java', 'SaslQuorumServerCallbackHandler.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\java\org\apache\zookeeper\server\quorum\flexible
# ['QuorumHierarchical.java', 'QuorumMaj.java', 'QuorumVerifier.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\java\org\apache\zookeeper\server\util
# ['ConfigUtils.java', 'KerberosUtil.java', 'OSMXBean.java', 'SerializeUtils.java', 'VerifyingFileFactory.java', 'ZxidUtils.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\java\org\apache\zookeeper\util
# ['PemReader.java', 'SecurityUtils.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\java\org\apache\zookeeper\version
# ['util']
# ['Info.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\java\org\apache\zookeeper\version\util
# ['VerGen.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\resources
# ['lib']
# ['git.properties', 'lastRevision.bat', 'lastRevision.sh', 'LICENSE.txt', 'NOTICE.txt', 'overview.html', 'pom.template']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\resources\lib
# ['cobertura', 'jdiff']
# ['jline-2.11.LICENSE.txt', 'json-simple-1.1.1.LICENSE.txt', 'log4j-1.2.17.LICENSE.txt', 'netty-all-4.1.29.Final.LICENSE.txt', 'slf4j-1.7.25.LICENSE.txt']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\resources\lib\cobertura
# ['README.txt']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\main\resources\lib\jdiff
# ['zookeeper_3.1.1.xml']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test
# ['java', 'resources']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\java
# ['org']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\java\org
# ['apache']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\java\org\apache
# ['zookeeper']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\java\org\apache\zookeeper
# ['client', 'common', 'server', 'test', 'util']
# ['ClientCanonicalizeTest.java', 'ClientCnxnSocketTest.java', 'ClientReconnectTest.java', 'ClientRequestTimeoutTest.java', 'CustomHostProviderTest.java', 'JaasConfiguration.java', 'JUnit4ZKTestRunner.java', 'MockPacket.java', 'MultiResponseTest.java', 'MultiTransactionRecordTest.java', 'PortAssignment.java', 'PortAssignmentTest.java', 'RemoveWatchesCmdTest.java', 'RemoveWatchesTest.java', 'SaslAuthTest.java', 'ServerConfigTest.java', 'TestableZooKeeper.java', 'VerGenTest.java', 'ZKParameterized.java', 'ZKTestCase.java', 'ZooKeeperTest.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\java\org\apache\zookeeper\client
# ['ZKClientConfigTest.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\java\org\apache\zookeeper\common
# ['AtomicFileWritingIdiomTest.java', 'BaseX509ParameterizedTestCase.java', 'FileChangeWatcherTest.java', 'FileKeyStoreLoaderBuilderProviderTest.java', 'JKSFileLoaderTest.java', 'KeyStoreFileTypeTest.java', 'PathUtilsTest.java', 'PEMFileLoaderTest.java', 'TimeTest.java', 'X509KeyType.java', 'X509TestContext.java', 'X509TestHelpers.java', 'X509UtilTest.java', 'ZKTrustManagerTest.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\java\org\apache\zookeeper\server
# ['admin', 'persistence', 'quorum', 'util']
# ['ByteBufferInputStreamTest.java', 'CRCTest.java', 'CreateContainerTest.java', 'CreateTTLTest.java', 'DatadirCleanupManagerTest.java', 'DataNodeTest.java', 'DataTreeTest.java', 'DeserializationPerfTest.java', 'Emulate353TTLTest.java', 'EphemeralTypeTest.java', 'FinalRequestProcessorTest.java', 'InvalidSnapCountTest.java', 'InvalidSnapshotTest.java', 'MockNIOServerCnxn.java', 'MockSelectorThread.java', 'MockServerCnxn.java', 'MultiOpSessionUpgradeTest.java', 'NettyServerCnxnTest.java', 'NIOServerCnxnFactoryTest.java', 'NIOServerCnxnTest.java', 'PrepRequestProcessorTest.java', 'PurgeTxnTest.java', 'ReferenceCountedACLCacheTest.java', 'SerializationPerfTest.java', 'ServerCnxnFactoryAccessor.java', 'ServerIdTest.java', 'ServerStatsTest.java', 'SessionTrackerTest.java', 'ToStringTest.java', 'WatchesPathReportTest.java', 'WatchesReportTest.java', 'WatchesSummaryTest.java', 'ZooKeeperServerBeanTest.java', 'ZooKeeperServerConfTest.java', 'ZooKeeperServerMainTest.java', 'ZooKeeperServerStartupTest.java', 'ZooKeeperServerTest.java', 'ZooKeeperThreadTest.java', 'ZxidRolloverTest.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\java\org\apache\zookeeper\server\admin
# ['CommandResponseTest.java', 'CommandsTest.java', 'JettyAdminServerTest.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\java\org\apache\zookeeper\server\persistence
# ['FileTxnLogTest.java', 'FileTxnSnapLogTest.java', 'TxnLogToolkitTest.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\java\org\apache\zookeeper\server\quorum
# ['auth']
# ['BufferStatsTest.java', 'CommitProcessorConcurrencyTest.java', 'CommitProcessorTest.java', 'EphemeralNodeDeletionTest.java', 'FLEBackwardElectionRoundTest.java', 'FLELostMessageTest.java', 'FLEOutOfElectionTest.java', 'FLETestUtils.java', 'FuzzySnapshotRelatedTest.java', 'LeaderBeanTest.java', 'LeaderWithObserverTest.java', 'LearnerHandlerTest.java', 'LearnerSnapshotThrottlerTest.java', 'LearnerTest.java', 'LocalPeerBeanTest.java', 'QuorumBeanTest.java', 'QuorumPeerConfigTest.java', 'QuorumPeerMainTest.java', 'QuorumPeerTest.java', 'QuorumPeerTestBase.java', 'QuorumRequestPipelineTest.java', 'QuorumServerTest.java', 'QuorumSSLTest.java', 'RaceConditionTest.java', 'ReconfigBackupTest.java', 'ReconfigDuringLeaderSyncTest.java', 'ReconfigFailureCasesTest.java', 'ReconfigLegacyTest.java', 'ReconfigRecoveryTest.java', 'ReconfigRollingRestartCompatibilityTest.java', 'RemotePeerBeanTest.java', 'StandaloneDisabledTest.java', 'StatCommandTest.java', 'StatResetCommandTest.java', 'UnifiedServerSocketModeDetectionTest.java', 'UnifiedServerSocketTest.java', 'WatchLeakTest.java', 'Zab1_0Test.java', 'ZabUtils.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\java\org\apache\zookeeper\server\quorum\auth
# ['KerberosSecurityTestcase.java', 'KerberosTestUtils.java', 'MiniKdc.java', 'MiniKdcTest.java', 'QuorumAuthTestBase.java', 'QuorumAuthUpgradeTest.java', 'QuorumDigestAuthTest.java', 'QuorumKerberosAuthTest.java', 'QuorumKerberosHostBasedAuthTest.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\java\org\apache\zookeeper\server\util
# ['PortForwarder.java', 'SerializeUtilsTest.java', 'VerifyingFileFactoryTest.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\java\org\apache\zookeeper\test
# ['ACLCountTest.java', 'ACLRootTest.java', 'ACLTest.java', 'AsyncHammerTest.java', 'AsyncOps.java', 'AsyncOpsTest.java', 'AsyncTest.java', 'AtomicFileOutputStreamTest.java', 'AuthTest.java', 'BufferSizeTest.java', 'ChrootAsyncTest.java', 'ChrootClientTest.java', 'ChrootTest.java', 'ClientBase.java', 'ClientHammerTest.java', 'ClientPortBindTest.java', 'ClientRetryTest.java', 'ClientSkipACLTest.java', 'ClientSSLTest.java', 'ClientTest.java', 'CnxManagerTest.java', 'ConnectStringParserTest.java', 'CreateModeTest.java', 'CreateTest.java', 'DisconnectableZooKeeper.java', 'DisconnectedWatcherTest.java', 'DuplicateLocalSessionUpgradeTest.java', 'EmptiedSnapshotRecoveryTest.java', 'EventTypeTest.java', 'FLENewEpochTest.java', 'FLEPredicateTest.java', 'FLERestartTest.java', 'FLETest.java', 'FLEZeroWeightTest.java', 'FollowerResyncConcurrencyTest.java', 'FourLetterWordsQuorumTest.java', 'FourLetterWordsTest.java', 'FourLetterWordsWhiteListTest.java', 'GetChildren2Test.java', 'GetProposalFromTxnTest.java', 'HierarchicalQuorumTest.java', 'IntegrityCheck.java', 'InvalidSnapshotTest.java', 'JMXEnv.java', 'KeeperStateTest.java', 'LeaderSessionTrackerTest.java', 'LENonTerminateTest.java', 'LETest.java', 'LoadFromLogNoServerTest.java', 'LoadFromLogTest.java', 'LocalSessionRequestTest.java', 'LocalSessionsOnlyTest.java', 'MaxCnxnsTest.java', 'MultiAsyncTransactionTest.java', 'MultiTransactionTest.java', 'NettyNettySuiteBase.java', 'NettyNettySuiteHammerTest.java', 'NettyNettySuiteTest.java', 'NIOConnectionFactoryFdLeakTest.java', 'NioNettySuiteBase.java', 'NioNettySuiteHammerTest.java', 'NioNettySuiteTest.java', 'NonRecoverableErrorTest.java', 'NullDataTest.java', 'ObserverHierarchicalQuorumTest.java', 'ObserverLETest.java', 'ObserverQuorumHammerTest.java', 'ObserverTest.java', 'OOMTest.java', 'OSMXBeanTest.java', 'QuorumBase.java', 'QuorumHammerTest.java', 'QuorumMajorityTest.java', 'QuorumQuotaTest.java', 'QuorumTest.java', 'QuorumUtil.java', 'QuorumUtilTest.java', 'QuorumZxidSyncTest.java', 'ReadOnlyModeTest.java', 'ReconfigExceptionTest.java', 'ReconfigMisconfigTest.java', 'ReconfigTest.java', 'RecoveryTest.java', 'RepeatStartupTest.java', 'RestoreCommittedLogTest.java', 'SaslAuthDesignatedClientTest.java', 'SaslAuthDesignatedServerTest.java', 'SaslAuthFailDesignatedClientTest.java', 'SaslAuthFailTest.java', 'SaslAuthMissingClientConfigTest.java', 'SaslClientTest.java', 'SaslSuperUserTest.java', 'ServerCnxnTest.java', 'SessionInvalidationTest.java', 'SessionTest.java', 'SessionTimeoutTest.java', 'SessionTrackerCheckTest.java', 'SessionUpgradeTest.java', 'SledgeHammer.java', 'SSLAuthTest.java', 'StandaloneTest.java', 'StaticHostProviderTest.java', 'StatTest.java', 'StringUtilTest.java', 'SyncCallTest.java', 'TestByteBufAllocator.java', 'TestByteBufAllocatorTestHelper.java', 'TestHammer.java', 'TestUtils.java', 'TruncateTest.java', 'WatchedEventTest.java', 'WatcherFuncTest.java', 'WatcherTest.java', 'WatchEventWhenAutoResetTest.java', 'X509AuthTest.java', 'ZkDatabaseCorruptionTest.java', 'ZooKeeperQuotaTest.java', 'ZooKeeperTestClient.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\java\org\apache\zookeeper\util
# ['PemReaderTest.java']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\resources
# ['data']
# ['checkstyle-noframes-sorted.xsl', 'checkstyle.xml', 'check_compatibility.py', 'findbugsExcludeFile.xml', 'log4j.properties', 'test-github-pr.sh', 'test-patch.properties', 'test-patch.sh', 'test-scripts.sh']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\resources\data
# ['buffersize', 'invalidsnap', 'kerberos', 'ssl', 'upgrade']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\resources\data\buffersize
# ['create', 'set', 'snapshot']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\resources\data\buffersize\create
# ['version-2']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\resources\data\buffersize\create\version-2
# ['log.1', 'snapshot.0']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\resources\data\buffersize\set
# ['version-2']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\resources\data\buffersize\set\version-2
# ['log.1', 'snapshot.0']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\resources\data\buffersize\snapshot
# ['version-2']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\resources\data\buffersize\snapshot\version-2
# ['log.1', 'snapshot.0', 'snapshot.2']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\resources\data\invalidsnap
# ['version-2']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\resources\data\invalidsnap\version-2
# ['log.1', 'log.274', 'log.42', 'log.63b', 'log.840', 'log.842', 'snapshot.0', 'snapshot.272', 'snapshot.273', 'snapshot.639', 'snapshot.83f', 'snapshot.841']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\resources\data\kerberos
# ['minikdc-krb5.conf', 'minikdc.ldiff']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\resources\data\ssl
# ['README.md', 'testKeyStore.jks', 'testTrustStore.jks']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\src\test\resources\data\upgrade
# ['log.100000001', 'log.100001bf0', 'snapshot.100000000', 'snapshot.100001bec']
# ----------
# open folder C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\zookeeper-server\version-2
# ['snapshot.0']
# ----------

# %% [markdown]
# ### 1.2 Check whether file or folder

# %%
import os

path = 'C:\\tools\\zookeeper\\apache-zookeeper-3.5.5'
print(os.path.isfile(path))
# Out:
# False

# %% [markdown]
# ### 1.3 Get final file/folder names from absolute path

# %%
import os

path = 'C:\\tools\\zookeeper\\apache-zookeeper-3.5.5'
print(os.path.basename)
# same
print(path.split('\\')[-1])
# Out:
# <function basename at 0x000001C0B0D1BDC0>
# apache-zookeeper-3.5.5

# %% [markdown]
# ### 1.4 Create folder

# %%
import os

dirpath = 'C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\\test'
if not os.path.exists(dirpath):
    os.mkdir(dirpath)

# %% [markdown]
# ### 1.5 Get path of Desktop

# %%
import os

desktop_path = os.path.join(os.path.expanduser("~"), 'Desktop')
print(desktop_path)
# Out:
# C:\Users\infra\Desktop

# %%
import os

def GetDesktopPath():
    return os.path.join(os.path.expanduser("~"), 'Desktop')
GetDesktopPath()
# Out:
# 'C:\\Users\\infra\\Desktop'

# %% [markdown]
# ### 1.6 Rename file/folder

# %%
import os

os.rename('C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\\test', 'C:\\tools\\zookeeper\\apache-zookeeper-3.5.5\\test123')  # rename folder
# os.rename('file1', 'file2') # rename files

# %% [markdown]
# ### 1.7 Batch Process files - 1

# %%
import os

"""
Alternative way to os.walk()
"""

path = 'C:\\tools\\zookeeper\\apache-zookeeper-3.5.5'
for file in os.scandir(path): 
    print(file.name, file.path)
# Out:
# bin C:\tools\zookeeper\apache-zookeeper-3.5.5\bin
# build.xml C:\tools\zookeeper\apache-zookeeper-3.5.5\build.xml
# conf C:\tools\zookeeper\apache-zookeeper-3.5.5\conf
# excludeFindBugsFilter.xml C:\tools\zookeeper\apache-zookeeper-3.5.5\excludeFindBugsFilter.xml
# ivy.xml C:\tools\zookeeper\apache-zookeeper-3.5.5\ivy.xml
# ivysettings.xml C:\tools\zookeeper\apache-zookeeper-3.5.5\ivysettings.xml
# LICENSE.txt C:\tools\zookeeper\apache-zookeeper-3.5.5\LICENSE.txt
# NOTICE.txt C:\tools\zookeeper\apache-zookeeper-3.5.5\NOTICE.txt
# owaspSuppressions.xml C:\tools\zookeeper\apache-zookeeper-3.5.5\owaspSuppressions.xml
# pom.xml C:\tools\zookeeper\apache-zookeeper-3.5.5\pom.xml
# README.md C:\tools\zookeeper\apache-zookeeper-3.5.5\README.md
# README_packaging.txt C:\tools\zookeeper\apache-zookeeper-3.5.5\README_packaging.txt
# test123 C:\tools\zookeeper\apache-zookeeper-3.5.5\test123
# zookeeper-assembly C:\tools\zookeeper\apache-zookeeper-3.5.5\zookeeper-assembly
# zookeeper-client C:\tools\zookeeper\apache-zookeeper-3.5.5\zookeeper-client
# zookeeper-contrib C:\tools\zookeeper\apache-zookeeper-3.5.5\zookeeper-contrib
# zookeeper-docs C:\tools\zookeeper\apache-zookeeper-3.5.5\zookeeper-docs
# zookeeper-it C:\tools\zookeeper\apache-zookeeper-3.5.5\zookeeper-it
# zookeeper-jute C:\tools\zookeeper\apache-zookeeper-3.5.5\zookeeper-jute
# zookeeper-recipes C:\tools\zookeeper\apache-zookeeper-3.5.5\zookeeper-recipes
# zookeeper-server C:\tools\zookeeper\apache-zookeeper-3.5.5\zookeeper-server

# %% [markdown]
# ### 1.8 Batch Process files - 2

# %%
import os 

path = 'C:\\tools\\zookeeper\\apache-zookeeper-3.5.5'
for file in os.listdir(path):
    print(file)
# Out:
# bin
# build.xml
# conf
# excludeFindBugsFilter.xml
# ivy.xml
# ivysettings.xml
# LICENSE.txt
# NOTICE.txt
# owaspSuppressions.xml
# pom.xml
# README.md
# README_packaging.txt
# test123
# zookeeper-assembly
# zookeeper-client
# zookeeper-contrib
# zookeeper-docs
# zookeeper-it
# zookeeper-jute
# zookeeper-recipes
# zookeeper-server

# %% [markdown]
# # 2. shutil Module

# %%
import shutil 

# move file or folder

shutil.move(r'.\practice.txt', r'.\文件夹1/') 
shutil.move(r'.\practice.txt', r'.\文件夹1/new.txt')

# %% [markdown]
# # 3. glob Module

# %% [markdown]
# ### Batch Process files - 3

# %%
import glob

"""
glob 最重要的功能就是搜索获取同一级或者各子级下符合条件的文件（绝对路径），非常适合写批处理的代码。有时候我们需要对大量文件进行相同操作，在写完针对一份文件的操作后，
只需要加上几行代码，就可以完成批处理全部文件的工作。

glob.glob() 是一个非常重要的方法，能够获取给定路径下文件的绝对路径，并且接受「通配符」搜索，大大拓宽了灵活程度，* 表示任意字符长度，**/* 的使用表示用通配符指代给定路径下的任何一层，
recursive 参数允许遍历搜索。

"""
    
for file in glob.glob('**/*', recursive=True): 
    print(file)
